# %% [markdown]
# Ensemble Learning with Sklearn

# %% [markdown]
# ## loading modules

# %%
import numpy as np  # Used for mathematical operations
import pandas as pd  # for loading CSV data
import matplotlib.pyplot as plt  # for plotting data
from sklearn.metrics import mean_squared_error # for checking performance

# %% [markdown]
# ## loading data

# %%
train_df=pd.read_csv('https://raw.githubusercontent.com/rufusseopa/Team_18_JHB_WhatTheHack_regression-predict-api-template/master/Data/Train.csv')
test_df=pd.read_csv('https://raw.githubusercontent.com/rufusseopa/Team_18_JHB_WhatTheHack_regression-predict-api-template/master/Data/Test.csv')
riders_df=pd.read_csv('https://raw.githubusercontent.com/rufusseopa/Team_18_JHB_WhatTheHack_regression-predict-api-template/master/Data/Riders.csv')
variable_df=pd.read_csv('https://raw.githubusercontent.com/rufusseopa/Team_18_JHB_WhatTheHack_regression-predict-api-template/master/Data/VariableDefinitions.csv')

# %%
data = pd.merge(train_df,riders_df,on ='Rider Id')

# %%
data.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_27440  User_Id_2642         Bike              3
# 2  Order_No_14170  User_Id_3339         Bike              3
# 3  Order_No_21727  User_Id_3523         Bike              3
# 4   Order_No_8301    User_Id_87         Bike              2
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        18
# 2             Business                        31
# 3             Personal                         2
# 4             Personal                        22
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5       3:41:17 PM                           18
# 2                             5      12:51:41 PM                           31
# 3                             2       7:12:10 AM                            2
# 4                             2      10:40:58 AM                           22
#
#    Confirmation - Weekday (Mo = 1)  ... Pickup Lat  Pickup Long  \
# 0                                5  ...  -1.317755    36.830370
# 1                                5  ...  -1.326774    36.787807
# 2                                5  ...  -1.255189    36.782203
# 3                                2  ...  -1.290315    36.757377
# 4                                2  ...  -1.273524    36.799220
#
#    Destination Lat Destination Long      Rider Id  \
# 0        -1.300406        36.829741  Rider_Id_432
# 1        -1.356237        36.904295  Rider_Id_432
# 2        -1.273412        36.818206  Rider_Id_432
# 3        -1.223520        36.802061  Rider_Id_432
# 4        -1.300431        36.752427  Rider_Id_432
#
#    Time from Pickup to Arrival No_Of_Orders   Age  Average_Rating  \
# 0                          745         1637  1309            13.8
# 1                         2886         1637  1309            13.8
# 2                         2615         1637  1309            13.8
# 3                         2986         1637  1309            13.8
# 4                         1602         1637  1309            13.8
#
#   No_of_Ratings
# 0           549
# 1           549
# 2           549
# 3           549
# 4           549
#
# [5 rows x 33 columns]

# %%
riders_df.describe()
# Out:
#        No_Of_Orders          Age  Average_Rating  No_of_Ratings
# count    960.000000   960.000000      960.000000     960.000000
# mean    1864.851042  1200.234375       13.412604     427.983333
# std     1880.337785   810.930171        2.675794     486.957931
# min        2.000000    96.000000        0.000000       0.000000
# 25%      261.750000   478.250000       13.500000      30.000000
# 50%     1475.500000  1021.000000       14.000000     223.000000
# 75%     2847.250000  1891.500000       14.300000     678.750000
# max     9756.000000  3764.000000       15.200000    2298.000000

# %%
data.dtypes
# Out:
# Order No                                      object
# User Id                                       object
# Vehicle Type                                  object
# Platform Type                                  int64
# Personal or Business                          object
# Placement - Day of Month                       int64
# Placement - Weekday (Mo = 1)                   int64
# Placement - Time                              object
# Confirmation - Day of Month                    int64
# Confirmation - Weekday (Mo = 1)                int64
# Confirmation - Time                           object
# Arrival at Pickup - Day of Month               int64
# Arrival at Pickup - Weekday (Mo = 1)           int64
# Arrival at Pickup - Time                      object
# Pickup - Day of Month                          int64
# Pickup - Weekday (Mo = 1)                      int64
# Pickup - Time                                 object
# Arrival at Destination - Day of Month          int64
# Arrival at Destination - Weekday (Mo = 1)      int64
# Arrival at Destination - Time                 object
# Distance (KM)                                  int64
# Temperature                                  float64
# Precipitation in millimeters                 float64
# Pickup Lat                                   float64
# Pickup Long                                  float64
# Destination Lat                              float64
# Destination Long                             float64
# Rider Id                                      object
# Time from Pickup to Arrival                    int64
# No_Of_Orders                                   int64
# Age                                            int64
# Average_Rating                               float64
# No_of_Ratings                                  int64
# dtype: object

# %%
data_dropped=data.drop(['Precipitation in millimeters','User Id','Vehicle Type','Rider Id ','Order No','No_of_Ratings',axis=1)
# Out:
#   File "<ipython-input-26-d6ee97dd5658>", line 1
#     data_dropped=data.drop(['Precipitation in millimeters','User Id','Vehicle Type','Rider Id ','Order No','No_of_Ratings',axis=1)
#                                                                                                                                ^
# SyntaxError: invalid syntax

# %%
df_num
# Out:
#        Platform Type  Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# 0                  3                         9                             5
# 1                  3                        18                             5
# 2                  3                        31                             5
# 3                  3                         2                             2
# 4                  2                        22                             2
# ...              ...                       ...                           ...
# 21196              3                        13                             2
# 21197              3                        21                             4
# 21198              3                        10                             1
# 21199              3                        29                             2
# 21200              3                        30                             5
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# 0                                9                                5
# 1                               18                                5
# 2                               31                                5
# 3                                2                                2
# 4                               22                                2
# ...                            ...                              ...
# 21196                           13                                2
# 21197                           21                                4
# 21198                           10                                1
# 21199                           29                                2
# 21200                           30                                5
#
#        Arrival at Pickup - Day of Month  Arrival at Pickup - Weekday (Mo = 1)  \
# 0                                     9                                     5
# 1                                    18                                     5
# 2                                    31                                     5
# 3                                     2                                     2
# 4                                    22                                     2
# ...                                 ...                                   ...
# 21196                                13                                     2
# 21197                                21                                     4
# 21198                                10                                     1
# 21199                                29                                     2
# 21200                                30                                     5
#
#        Pickup - Day of Month  Pickup - Weekday (Mo = 1)  \
# 0                          9                          5
# 1                         18                          5
# 2                         31                          5
# 3                          2                          2
# 4                         22                          2
# ...                      ...                        ...
# 21196                     13                          2
# 21197                     21                          4
# 21198                     10                          1
# 21199                     29                          2
# 21200                     30                          5
#
#        Arrival at Destination - Day of Month  ...  \
# 0                                          9  ...
# 1                                         18  ...
# 2                                         31  ...
# 3                                          2  ...
# 4                                         22  ...
# ...                                      ...  ...
# 21196                                     13  ...
# 21197                                     21  ...
# 21198                                     10  ...
# 21199                                     29  ...
# 21200                                     30  ...
#
#        Precipitation in millimeters  Pickup Lat  Pickup Long  Destination Lat  \
# 0                               NaN   -1.317755    36.830370        -1.300406
# 1                               NaN   -1.326774    36.787807        -1.356237
# 2                               NaN   -1.255189    36.782203        -1.273412
# 3                               NaN   -1.290315    36.757377        -1.223520
# 4                               NaN   -1.273524    36.799220        -1.300431
# ...                             ...         ...          ...              ...
# 21196                           NaN   -1.265003    36.812624        -1.265432
# 21197                           NaN   -1.269609    36.825741        -1.278067
# 21198                           NaN   -1.250823    36.789526        -1.285850
# 21199                           NaN   -1.291787    36.787267        -1.298575
# 21200                           NaN   -1.248278    36.884092        -1.286808
#
#        Destination Long  Time from Pickup to Arrival  No_Of_Orders   Age  \
# 0             36.829741                          745          1637  1309
# 1             36.904295                         2886          1637  1309
# 2             36.818206                         2615          1637  1309
# 3             36.802061                         2986          1637  1309
# 4             36.752427                         1602          1637  1309
# ...                 ...                          ...           ...   ...
# 21196         36.795034                          919          5770  1793
# 21197         36.783487                         2331           102   873
# 21198         36.830629                         2418             5   105
# 21199         36.808800                          717             5   448
# 21200         36.821940                         1647           241  1109
#
#        Average_Rating  No_of_Ratings
# 0                13.8            549
# 1                13.8            549
# 2                13.8            549
# 3                13.8            549
# 4                13.8            549
# ...               ...            ...
# 21196            14.2           2205
# 21197            13.7             32
# 21198             0.0              0
# 21199            15.0              2
# 21200            13.7             73
#
# [21201 rows x 23 columns]
