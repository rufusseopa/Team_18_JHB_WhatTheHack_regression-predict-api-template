# %% [markdown]
# ## Imports

# %%
# Import modules
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import numpy as np

# Figures inline and set visualization style
# %matplotlib inline
sns.set()

# %% [markdown]
# ## Importing Datasets
# **Train and Test data**

# %%
train_df=pd.read_csv('https://raw.githubusercontent.com/rufusseopa/Team_18_JHB_WhatTheHack_regression-predict-api-template/master/Data/Train.csv', index_col = 0)

# %%
train_df.head()
# Out:
#                      User Id Vehicle Type  Platform Type Personal or Business  \
# Order No
# Order_No_4211    User_Id_633         Bike              3             Business
# Order_No_25375  User_Id_2285         Bike              3             Personal
# Order_No_1899    User_Id_265         Bike              3             Business
# Order_No_9336   User_Id_1402         Bike              3             Business
# Order_No_27883  User_Id_1737         Bike              1             Personal
#
#                 Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# Order No
# Order_No_4211                          9                             5
# Order_No_25375                        12                             5
# Order_No_1899                         30                             2
# Order_No_9336                         15                             5
# Order_No_27883                        13                             1
#
#                Placement - Time  Confirmation - Day of Month  \
# Order No
# Order_No_4211        9:35:46 AM                            9
# Order_No_25375      11:16:16 AM                           12
# Order_No_1899       12:39:25 PM                           30
# Order_No_9336        9:25:34 AM                           15
# Order_No_27883       9:55:18 AM                           13
#
#                 Confirmation - Weekday (Mo = 1) Confirmation - Time  ...  \
# Order No                                                             ...
# Order_No_4211                                 5          9:40:10 AM  ...
# Order_No_25375                                5         11:23:21 AM  ...
# Order_No_1899                                 2         12:42:44 PM  ...
# Order_No_9336                                 5          9:26:05 AM  ...
# Order_No_27883                                1          9:56:18 AM  ...
#
#                 Arrival at Destination - Time  Distance (KM) Temperature  \
# Order No
# Order_No_4211                     10:39:55 AM              4        20.4
# Order_No_25375                    12:17:22 PM             16        26.4
# Order_No_1899                      1:00:38 PM              3         NaN
# Order_No_9336                     10:05:27 AM              9        19.2
# Order_No_27883                    10:25:37 AM              9        15.4
#
#                 Precipitation in millimeters  Pickup Lat Pickup Long  \
# Order No
# Order_No_4211                            NaN   -1.317755   36.830370
# Order_No_25375                           NaN   -1.351453   36.899315
# Order_No_1899                            NaN   -1.308284   36.843419
# Order_No_9336                            NaN   -1.281301   36.832396
# Order_No_27883                           NaN   -1.266597   36.792118
#
#                 Destination Lat  Destination Long      Rider Id  \
# Order No
# Order_No_4211         -1.300406         36.829741  Rider_Id_432
# Order_No_25375        -1.295004         36.814358  Rider_Id_856
# Order_No_1899         -1.300921         36.828195  Rider_Id_155
# Order_No_9336         -1.257147         36.795063  Rider_Id_855
# Order_No_27883        -1.295041         36.809817  Rider_Id_770
#
#                 Time from Pickup to Arrival
# Order No
# Order_No_4211                           745
# Order_No_25375                         1993
# Order_No_1899                           455
# Order_No_9336                          1341
# Order_No_27883                         1214
#
# [5 rows x 28 columns]

# %%
test_df=pd.read_csv('https://raw.githubusercontent.com/rufusseopa/Team_18_JHB_WhatTheHack_regression-predict-api-template/master/Data/Test.csv', index_col = 0)

# %%
test_df.head()
# Out:
#                      User Id Vehicle Type  Platform Type Personal or Business  \
# Order No
# Order_No_19248  User_Id_3355         Bike              3             Business
# Order_No_12736  User_Id_3647         Bike              3             Business
# Order_No_768    User_Id_2154         Bike              3             Business
# Order_No_15332  User_Id_2910         Bike              3             Business
# Order_No_21373  User_Id_1205         Bike              3             Business
#
#                 Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# Order No
# Order_No_19248                        27                             3
# Order_No_12736                        17                             5
# Order_No_768                          27                             4
# Order_No_15332                        17                             1
# Order_No_21373                        11                             2
#
#                Placement - Time  Confirmation - Day of Month  \
# Order No
# Order_No_19248       4:44:10 PM                           27
# Order_No_12736      12:57:35 PM                           17
# Order_No_768        11:08:14 AM                           27
# Order_No_15332       1:51:35 PM                           17
# Order_No_21373      11:30:28 AM                           11
#
#                 Confirmation - Weekday (Mo = 1) Confirmation - Time  ...  \
# Order No                                                             ...
# Order_No_19248                                3          4:44:29 PM  ...
# Order_No_12736                                5         12:59:17 PM  ...
# Order_No_768                                  4         11:25:05 AM  ...
# Order_No_15332                                1          1:53:27 PM  ...
# Order_No_21373                                2         11:34:45 AM  ...
#
#                 Pickup - Weekday (Mo = 1)  Pickup - Time Distance (KM)  \
# Order No
# Order_No_19248                          3     5:06:47 PM             8
# Order_No_12736                          5     1:25:37 PM             5
# Order_No_768                            4    11:57:54 AM             5
# Order_No_15332                          1     2:16:52 PM             5
# Order_No_21373                          2    11:56:04 AM             6
#
#                 Temperature  Precipitation in millimeters Pickup Lat  \
# Order No
# Order_No_19248          NaN                           NaN  -1.333275
# Order_No_12736          NaN                           NaN  -1.272639
# Order_No_768           22.8                           NaN  -1.290894
# Order_No_15332         24.5                           NaN  -1.290503
# Order_No_21373         24.4                           NaN  -1.281081
#
#                 Pickup Long  Destination Lat  Destination Long      Rider Id
# Order No
# Order_No_19248    36.870815        -1.305249         36.822390  Rider_Id_192
# Order_No_12736    36.794723        -1.277007         36.823907  Rider_Id_868
# Order_No_768      36.822971        -1.276574         36.851365   Rider_Id_26
# Order_No_15332    36.809646        -1.303382         36.790658  Rider_Id_685
# Order_No_21373    36.814423        -1.266467         36.792161  Rider_Id_858
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Concatenate train_df and test_df

# %%
data = pd.concat([train_df, test_df])
data['User Id']=data['User Id'].str.rpartition('_')[2]

# %%
data.head()
# Out:
#                User Id Vehicle Type  Platform Type Personal or Business  \
# Order No
# Order_No_4211      633         Bike              3             Business
# Order_No_25375    2285         Bike              3             Personal
# Order_No_1899      265         Bike              3             Business
# Order_No_9336     1402         Bike              3             Business
# Order_No_27883    1737         Bike              1             Personal
#
#                 Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# Order No
# Order_No_4211                          9                             5
# Order_No_25375                        12                             5
# Order_No_1899                         30                             2
# Order_No_9336                         15                             5
# Order_No_27883                        13                             1
#
#                Placement - Time  Confirmation - Day of Month  \
# Order No
# Order_No_4211        9:35:46 AM                            9
# Order_No_25375      11:16:16 AM                           12
# Order_No_1899       12:39:25 PM                           30
# Order_No_9336        9:25:34 AM                           15
# Order_No_27883       9:55:18 AM                           13
#
#                 Confirmation - Weekday (Mo = 1) Confirmation - Time  ...  \
# Order No                                                             ...
# Order_No_4211                                 5          9:40:10 AM  ...
# Order_No_25375                                5         11:23:21 AM  ...
# Order_No_1899                                 2         12:42:44 PM  ...
# Order_No_9336                                 5          9:26:05 AM  ...
# Order_No_27883                                1          9:56:18 AM  ...
#
#                 Arrival at Destination - Time  Distance (KM) Temperature  \
# Order No
# Order_No_4211                     10:39:55 AM              4        20.4
# Order_No_25375                    12:17:22 PM             16        26.4
# Order_No_1899                      1:00:38 PM              3         NaN
# Order_No_9336                     10:05:27 AM              9        19.2
# Order_No_27883                    10:25:37 AM              9        15.4
#
#                 Precipitation in millimeters  Pickup Lat Pickup Long  \
# Order No
# Order_No_4211                            NaN   -1.317755   36.830370
# Order_No_25375                           NaN   -1.351453   36.899315
# Order_No_1899                            NaN   -1.308284   36.843419
# Order_No_9336                            NaN   -1.281301   36.832396
# Order_No_27883                           NaN   -1.266597   36.792118
#
#                 Destination Lat  Destination Long      Rider Id  \
# Order No
# Order_No_4211         -1.300406         36.829741  Rider_Id_432
# Order_No_25375        -1.295004         36.814358  Rider_Id_856
# Order_No_1899         -1.300921         36.828195  Rider_Id_155
# Order_No_9336         -1.257147         36.795063  Rider_Id_855
# Order_No_27883        -1.295041         36.809817  Rider_Id_770
#
#                 Time from Pickup to Arrival
# Order No
# Order_No_4211                         745.0
# Order_No_25375                       1993.0
# Order_No_1899                         455.0
# Order_No_9336                        1341.0
# Order_No_27883                       1214.0
#
# [5 rows x 28 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28269 entries, Order_No_4211 to Order_No_1603
# Data columns (total 28 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   User Id                                    28269 non-null  object
#  1   Vehicle Type                               28269 non-null  object
#  2   Platform Type                              28269 non-null  int64
#  3   Personal or Business                       28269 non-null  object
#  4   Placement - Day of Month                   28269 non-null  int64
#  5   Placement - Weekday (Mo = 1)               28269 non-null  int64
#  6   Placement - Time                           28269 non-null  object
#  7   Confirmation - Day of Month                28269 non-null  int64
#  8   Confirmation - Weekday (Mo = 1)            28269 non-null  int64
#  9   Confirmation - Time                        28269 non-null  object
#  10  Arrival at Pickup - Day of Month           28269 non-null  int64
#  11  Arrival at Pickup - Weekday (Mo = 1)       28269 non-null  int64
#  12  Arrival at Pickup - Time                   28269 non-null  object
#  13  Pickup - Day of Month                      28269 non-null  int64
#  14  Pickup - Weekday (Mo = 1)                  28269 non-null  int64
#  15  Pickup - Time                              28269 non-null  object
#  16  Arrival at Destination - Day of Month      21201 non-null  float64
#  17  Arrival at Destination - Weekday (Mo = 1)  21201 non-null  float64
#  18  Arrival at Destination - Time              21201 non-null  object
#  19  Distance (KM)                              28269 non-null  int64
#  20  Temperature                                22466 non-null  float64
#  21  Precipitation in millimeters               751 non-null    float64
#  22  Pickup Lat                                 28269 non-null  float64
#  23  Pickup Long                                28269 non-null  float64
#  24  Destination Lat                            28269 non-null  float64
#  25  Destination Long                           28269 non-null  float64
#  26  Rider Id                                   28269 non-null  object
#  27  Time from Pickup to Arrival                21201 non-null  float64
# dtypes: float64(9), int64(10), object(9)
# memory usage: 6.3+ MB

# %% [markdown]
# ## Drop columns and fill-in missing values

# %%
df=data.drop(['User Id',
              'Placement - Day of Month',
              'Placement - Weekday (Mo = 1)',
              'Confirmation - Day of Month',
              'Confirmation - Weekday (Mo = 1)',
              'Arrival at Pickup - Day of Month',
              'Arrival at Pickup - Weekday (Mo = 1)',
              'Pickup - Day of Month',
              'Pickup - Weekday (Mo = 1)',
              'Arrival at Destination - Weekday (Mo = 1)',
              'Arrival at Destination - Day of Month',
              'Precipitation in millimeters',
              'Pickup Lat',
              'Pickup Long',
              'Destination Lat',
              'Destination Long','Rider Id'], axis=1)

# %%
df.head()
# Out:
#                Vehicle Type  Platform Type Personal or Business  \
# Order No
# Order_No_4211          Bike              3             Business
# Order_No_25375         Bike              3             Personal
# Order_No_1899          Bike              3             Business
# Order_No_9336          Bike              3             Business
# Order_No_27883         Bike              1             Personal
#
#                Placement - Time Confirmation - Time Arrival at Pickup - Time  \
# Order No
# Order_No_4211        9:35:46 AM          9:40:10 AM              10:04:47 AM
# Order_No_25375      11:16:16 AM         11:23:21 AM              11:40:22 AM
# Order_No_1899       12:39:25 PM         12:42:44 PM              12:49:34 PM
# Order_No_9336        9:25:34 AM          9:26:05 AM               9:37:56 AM
# Order_No_27883       9:55:18 AM          9:56:18 AM              10:03:53 AM
#
#                Pickup - Time Arrival at Destination - Time  Distance (KM)  \
# Order No
# Order_No_4211    10:27:30 AM                   10:39:55 AM              4
# Order_No_25375   11:44:09 AM                   12:17:22 PM             16
# Order_No_1899    12:53:03 PM                    1:00:38 PM              3
# Order_No_9336     9:43:06 AM                   10:05:27 AM              9
# Order_No_27883   10:05:23 AM                   10:25:37 AM              9
#
#                 Temperature  Time from Pickup to Arrival
# Order No
# Order_No_4211          20.4                        745.0
# Order_No_25375         26.4                       1993.0
# Order_No_1899           NaN                        455.0
# Order_No_9336          19.2                       1341.0
# Order_No_27883         15.4                       1214.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28269 entries, Order_No_4211 to Order_No_1603
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Vehicle Type                   28269 non-null  object
#  1   Platform Type                  28269 non-null  int64
#  2   Personal or Business           28269 non-null  object
#  3   Placement - Time               28269 non-null  object
#  4   Confirmation - Time            28269 non-null  object
#  5   Arrival at Pickup - Time       28269 non-null  object
#  6   Pickup - Time                  28269 non-null  object
#  7   Arrival at Destination - Time  21201 non-null  object
#  8   Distance (KM)                  28269 non-null  int64
#  9   Temperature                    22466 non-null  float64
#  10  Time from Pickup to Arrival    21201 non-null  float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 2.6+ MB

# %% [markdown]
# **Change all time variables to seconds**

# %%
df['Placement - Time'] = pd.to_timedelta(df['Placement - Time'])
df['Confirmation - Time'] = pd.to_timedelta(df['Confirmation - Time'])
df['Arrival at Pickup - Time'] = pd.to_timedelta(df['Arrival at Pickup - Time'])
df['Pickup - Time'] = pd.to_timedelta(df['Pickup - Time'])
df['Arrival at Destination - Time'] = pd.to_timedelta(df['Arrival at Destination - Time'])

# %%
df['Placement - Time'] = df['Placement - Time'].dt.total_seconds()
df['Confirmation - Time'] = df['Confirmation - Time'].dt.total_seconds()
df['Arrival at Pickup - Time'] = df['Arrival at Pickup - Time'].dt.total_seconds()
df['Pickup - Time'] = df['Pickup - Time'].dt.total_seconds()
df['Arrival at Destination - Time'] = df['Arrival at Destination - Time'].dt.total_seconds()

# %%
df.head()
# Out:
#                Vehicle Type  Platform Type Personal or Business  \
# Order No
# Order_No_4211          Bike              3             Business
# Order_No_25375         Bike              3             Personal
# Order_No_1899          Bike              3             Business
# Order_No_9336          Bike              3             Business
# Order_No_27883         Bike              1             Personal
#
#                 Placement - Time  Confirmation - Time  \
# Order No
# Order_No_4211            34546.0              34810.0
# Order_No_25375           40576.0              41001.0
# Order_No_1899            45565.0              45764.0
# Order_No_9336            33934.0              33965.0
# Order_No_27883           35718.0              35778.0
#
#                 Arrival at Pickup - Time  Pickup - Time  \
# Order No
# Order_No_4211                    36287.0        37650.0
# Order_No_25375                   42022.0        42249.0
# Order_No_1899                    46174.0        46383.0
# Order_No_9336                    34676.0        34986.0
# Order_No_27883                   36233.0        36323.0
#
#                 Arrival at Destination - Time  Distance (KM)  Temperature  \
# Order No
# Order_No_4211                         38395.0              4         20.4
# Order_No_25375                        44242.0             16         26.4
# Order_No_1899                          3638.0              3          NaN
# Order_No_9336                         36327.0              9         19.2
# Order_No_27883                        37537.0              9         15.4
#
#                 Time from Pickup to Arrival
# Order No
# Order_No_4211                         745.0
# Order_No_25375                       1993.0
# Order_No_1899                         455.0
# Order_No_9336                        1341.0
# Order_No_27883                       1214.0

# %% [markdown]
# **Plot the distribution of 'Temperature', 'Arrival at Destination - Time' and 'Time from Pickup to Arrival'**

# %%
_ = plt.hist(df['Temperature'], bins='auto') 
plt.title('Distribution of Temperature')
plt.show()

# %%
_ = plt.hist(df['Time from Pickup to Arrival'], bins='auto') 
plt.title('Distribution of Time from Pickup to Arrival')
plt.show()

# %%
_ = plt.hist(df['Arrival at Destination - Time'], bins='auto') 
plt.title('Distribution of Arrival at Destination - Time')
plt.show()

# %% [markdown]
# **Impute Temperature with mean and Time from Pickup to Arrival with median**

# %%
df['Temperature'] = df.Temperature.fillna(df.Temperature.mean())

# %%
df['Arrival_at_Destination_Time'] = df['Arrival at Destination - Time']
df['Time_from_Pickup_to_Arrival'] = df['Time from Pickup to Arrival']

# %%
df.head()
# Out:
#                Vehicle Type  Platform Type Personal or Business  \
# Order No
# Order_No_4211          Bike              3             Business
# Order_No_25375         Bike              3             Personal
# Order_No_1899          Bike              3             Business
# Order_No_9336          Bike              3             Business
# Order_No_27883         Bike              1             Personal
#
#                 Placement - Time  Confirmation - Time  \
# Order No
# Order_No_4211            34546.0              34810.0
# Order_No_25375           40576.0              41001.0
# Order_No_1899            45565.0              45764.0
# Order_No_9336            33934.0              33965.0
# Order_No_27883           35718.0              35778.0
#
#                 Arrival at Pickup - Time  Pickup - Time  \
# Order No
# Order_No_4211                    36287.0        37650.0
# Order_No_25375                   42022.0        42249.0
# Order_No_1899                    46174.0        46383.0
# Order_No_9336                    34676.0        34986.0
# Order_No_27883                   36233.0        36323.0
#
#                 Arrival at Destination - Time  Distance (KM)  Temperature  \
# Order No
# Order_No_4211                         38395.0              4    20.400000
# Order_No_25375                        44242.0             16    26.400000
# Order_No_1899                          3638.0              3    23.255689
# Order_No_9336                         36327.0              9    19.200000
# Order_No_27883                        37537.0              9    15.400000
#
#                 Time from Pickup to Arrival  Arrival_at_Destination_Time  \
# Order No
# Order_No_4211                         745.0                      38395.0
# Order_No_25375                       1993.0                      44242.0
# Order_No_1899                         455.0                       3638.0
# Order_No_9336                        1341.0                      36327.0
# Order_No_27883                       1214.0                      37537.0
#
#                 Time_from_Pickup_to_Arrival
# Order No
# Order_No_4211                         745.0
# Order_No_25375                       1993.0
# Order_No_1899                         455.0
# Order_No_9336                        1341.0
# Order_No_27883                       1214.0

# %%
#df['Time from Pickup to Arrival'] = df.'Time from Pickup to Arrival'.fillna(df.'Time from Pickup to Arrival'.mean())

# %%
df=df.drop(['Time from Pickup to Arrival', 'Arrival at Destination - Time'], axis=1)

# %%
df.head()
# Out:
#                Vehicle Type  Platform Type Personal or Business  \
# Order No
# Order_No_4211          Bike              3             Business
# Order_No_25375         Bike              3             Personal
# Order_No_1899          Bike              3             Business
# Order_No_9336          Bike              3             Business
# Order_No_27883         Bike              1             Personal
#
#                 Placement - Time  Confirmation - Time  \
# Order No
# Order_No_4211            34546.0              34810.0
# Order_No_25375           40576.0              41001.0
# Order_No_1899            45565.0              45764.0
# Order_No_9336            33934.0              33965.0
# Order_No_27883           35718.0              35778.0
#
#                 Arrival at Pickup - Time  Pickup - Time  Distance (KM)  \
# Order No
# Order_No_4211                    36287.0        37650.0              4
# Order_No_25375                   42022.0        42249.0             16
# Order_No_1899                    46174.0        46383.0              3
# Order_No_9336                    34676.0        34986.0              9
# Order_No_27883                   36233.0        36323.0              9
#
#                 Temperature  Arrival_at_Destination_Time  \
# Order No
# Order_No_4211     20.400000                      38395.0
# Order_No_25375    26.400000                      44242.0
# Order_No_1899     23.255689                       3638.0
# Order_No_9336     19.200000                      36327.0
# Order_No_27883    15.400000                      37537.0
#
#                 Time_from_Pickup_to_Arrival
# Order No
# Order_No_4211                         745.0
# Order_No_25375                       1993.0
# Order_No_1899                         455.0
# Order_No_9336                        1341.0
# Order_No_27883                       1214.0

# %% [markdown]
# **Impute 'Arrival at Destination - Time' and 'Time_from_Pickup_to_Arrival' with median**

# %%
df['Arrival_at_Destination_Time'] = df.Arrival_at_Destination_Time.fillna(df.Arrival_at_Destination_Time.median())
df['Time_from_Pickup_to_Arrival'] = df.Time_from_Pickup_to_Arrival.fillna(df.Time_from_Pickup_to_Arrival.median())

# %%
df.head()
# Out:
#                Vehicle Type  Platform Type Personal or Business  \
# Order No
# Order_No_4211          Bike              3             Business
# Order_No_25375         Bike              3             Personal
# Order_No_1899          Bike              3             Business
# Order_No_9336          Bike              3             Business
# Order_No_27883         Bike              1             Personal
#
#                 Placement - Time  Confirmation - Time  \
# Order No
# Order_No_4211            34546.0              34810.0
# Order_No_25375           40576.0              41001.0
# Order_No_1899            45565.0              45764.0
# Order_No_9336            33934.0              33965.0
# Order_No_27883           35718.0              35778.0
#
#                 Arrival at Pickup - Time  Pickup - Time  Distance (KM)  \
# Order No
# Order_No_4211                    36287.0        37650.0              4
# Order_No_25375                   42022.0        42249.0             16
# Order_No_1899                    46174.0        46383.0              3
# Order_No_9336                    34676.0        34986.0              9
# Order_No_27883                   36233.0        36323.0              9
#
#                 Temperature  Arrival_at_Destination_Time  \
# Order No
# Order_No_4211     20.400000                      38395.0
# Order_No_25375    26.400000                      44242.0
# Order_No_1899     23.255689                       3638.0
# Order_No_9336     19.200000                      36327.0
# Order_No_27883    15.400000                      37537.0
#
#                 Time_from_Pickup_to_Arrival
# Order No
# Order_No_4211                         745.0
# Order_No_25375                       1993.0
# Order_No_1899                         455.0
# Order_No_9336                        1341.0
# Order_No_27883                       1214.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28269 entries, Order_No_4211 to Order_No_1603
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Vehicle Type                 28269 non-null  object
#  1   Platform Type                28269 non-null  int64
#  2   Personal or Business         28269 non-null  object
#  3   Placement - Time             28269 non-null  float64
#  4   Confirmation - Time          28269 non-null  float64
#  5   Arrival at Pickup - Time     28269 non-null  float64
#  6   Pickup - Time                28269 non-null  float64
#  7   Distance (KM)                28269 non-null  int64
#  8   Temperature                  28269 non-null  float64
#  9   Arrival_at_Destination_Time  28269 non-null  float64
#  10  Time_from_Pickup_to_Arrival  28269 non-null  float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 2.6+ MB

# %%
df.describe().T
# Out:
#                                count          mean           std     min  \
# Platform Type                28269.0      2.752167      0.624872     1.0
# Placement - Time             28269.0  26100.323110  14705.655079  3601.0
# Confirmation - Time          28269.0  25851.617708  14701.465439  3600.0
# Arrival at Pickup - Time     28269.0  25457.172946  14725.759706  3600.0
# Pickup - Time                28269.0  25091.207117  14732.889084  3600.0
# Distance (KM)                28269.0      9.494641      5.645726     1.0
# Temperature                  28269.0     23.255689      3.217789    11.2
# Arrival_at_Destination_Time  28269.0  22800.164633  12850.649383  3600.0
# Time_from_Pickup_to_Arrival  28269.0   1509.935725    858.845362     1.0
#
#                                  25%           50%      75%      max
# Platform Type                    3.0      3.000000      3.0      4.0
# Placement - Time             11139.0  31570.000000  39799.0  46799.0
# Confirmation - Time          11215.0  30935.000000  39733.0  46799.0
# Arrival at Pickup - Time     11236.0  26179.000000  39723.0  46798.0
# Pickup - Time                11272.0  20818.000000  39767.0  46799.0
# Distance (KM)                    5.0      8.000000     13.0     49.0
# Temperature                     21.4     23.255689     25.3     32.1
# Arrival_at_Destination_Time  13501.0  18795.000000  36695.0  46799.0
# Time_from_Pickup_to_Arrival   1047.0   1369.000000   1768.0   7883.0

# %% [markdown]
# ## Create Dummy variables for categorical columns

# %%
df_updated = pd.get_dummies(df)

# %%
# Ensure that column names have underscores instead of whitespaces
df_updated.columns = [col.replace(" ","_") for col in df_updated.columns]

# %%
df_updated.head()
# Out:
#                 Platform_Type  Placement_-_Time  Confirmation_-_Time  \
# Order No
# Order_No_4211               3           34546.0              34810.0
# Order_No_25375              3           40576.0              41001.0
# Order_No_1899               3           45565.0              45764.0
# Order_No_9336               3           33934.0              33965.0
# Order_No_27883              1           35718.0              35778.0
#
#                 Arrival_at_Pickup_-_Time  Pickup_-_Time  Distance_(KM)  \
# Order No
# Order_No_4211                    36287.0        37650.0              4
# Order_No_25375                   42022.0        42249.0             16
# Order_No_1899                    46174.0        46383.0              3
# Order_No_9336                    34676.0        34986.0              9
# Order_No_27883                   36233.0        36323.0              9
#
#                 Temperature  Arrival_at_Destination_Time  \
# Order No
# Order_No_4211     20.400000                      38395.0
# Order_No_25375    26.400000                      44242.0
# Order_No_1899     23.255689                       3638.0
# Order_No_9336     19.200000                      36327.0
# Order_No_27883    15.400000                      37537.0
#
#                 Time_from_Pickup_to_Arrival  Vehicle_Type_Bike  \
# Order No
# Order_No_4211                         745.0                  1
# Order_No_25375                       1993.0                  1
# Order_No_1899                         455.0                  1
# Order_No_9336                        1341.0                  1
# Order_No_27883                       1214.0                  1
#
#                 Personal_or_Business_Business  Personal_or_Business_Personal
# Order No
# Order_No_4211                               1                              0
# Order_No_25375                              0                              1
# Order_No_1899                               1                              0
# Order_No_9336                               1                              0
# Order_No_27883                              0                              1

# %%
# To avoid the dummy variable trap one of the Personal_or_Business_Business/_Peronal variables should be dropped
df_updated2 = df_updated.drop(['Personal_or_Business_Personal'], axis=1)

# %%
df_updated2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28269 entries, Order_No_4211 to Order_No_1603
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Platform_Type                  28269 non-null  int64
#  1   Placement_-_Time               28269 non-null  float64
#  2   Confirmation_-_Time            28269 non-null  float64
#  3   Arrival_at_Pickup_-_Time       28269 non-null  float64
#  4   Pickup_-_Time                  28269 non-null  float64
#  5   Distance_(KM)                  28269 non-null  int64
#  6   Temperature                    28269 non-null  float64
#  7   Arrival_at_Destination_Time    28269 non-null  float64
#  8   Time_from_Pickup_to_Arrival    28269 non-null  float64
#  9   Vehicle_Type_Bike              28269 non-null  uint8
#  10  Personal_or_Business_Business  28269 non-null  uint8
# dtypes: float64(7), int64(2), uint8(2)
# memory usage: 2.2+ MB

# %% [markdown]
# ## Fitting the Multivariable Regression Model

# %%
# import regression module
from sklearn.linear_model import LinearRegression

# split predictors and response
X = df_updated2.drop(['Time_from_Pickup_to_Arrival'], axis=1)
y = df_updated2['Time_from_Pickup_to_Arrival']

# %%
# create model object
lm = LinearRegression()

# %%
# import train/test split module
from sklearn.model_selection import train_test_split

# %%
# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
# train model
lm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## Assessing Model Accuracy

# %%
#Predict y
y_pred = lm.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.2347188922864566

# %%
from sklearn.metrics import mean_squared_error 
from math import sqrt

rmse = sqrt(mean_squared_error(y_test,y_pred))
print('Root Mean Square Error:', rmse)
# Out:
# Root Mean Square Error: 755.3625090844657

# %% [markdown]
# ## Improve model accuracy

# %% [markdown]
# **Check for linearity between the response and the predictors**
