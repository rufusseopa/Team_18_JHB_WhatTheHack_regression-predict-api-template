# %% [markdown]
# <a href="https://colab.research.google.com/github/rufusseopa/Team_18_JHB_WhatTheHack_regression-predict-api-template/blob/master/Predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Modules to be used**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# training data

# %%
train_df=pd.read_csv('https://raw.githubusercontent.com/rufusseopa/Team_18_JHB_WhatTheHack_regression-predict-api-template/master/Data/Train.csv')

# %%
train_df.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
#
#    Confirmation - Weekday (Mo = 1)  ... Arrival at Destination - Time  \
# 0                                5  ...                   10:39:55 AM
# 1                                5  ...                   12:17:22 PM
# 2                                2  ...                    1:00:38 PM
# 3                                5  ...                   10:05:27 AM
# 4                                1  ...                   10:25:37 AM
#
#    Distance (KM)  Temperature Precipitation in millimeters  Pickup Lat  \
# 0              4         20.4                          NaN   -1.317755
# 1             16         26.4                          NaN   -1.351453
# 2              3          NaN                          NaN   -1.308284
# 3              9         19.2                          NaN   -1.281301
# 4              9         15.4                          NaN   -1.266597
#
#    Pickup Long Destination Lat  Destination Long      Rider Id  \
# 0    36.830370       -1.300406         36.829741  Rider_Id_432
# 1    36.899315       -1.295004         36.814358  Rider_Id_856
# 2    36.843419       -1.300921         36.828195  Rider_Id_155
# 3    36.832396       -1.257147         36.795063  Rider_Id_855
# 4    36.792118       -1.295041         36.809817  Rider_Id_770
#
#   Time from Pickup to Arrival
# 0                         745
# 1                        1993
# 2                         455
# 3                        1341
# 4                        1214
#
# [5 rows x 29 columns]

# %% [markdown]
# test data

# %%
test_df=pd.read_csv('https://raw.githubusercontent.com/rufusseopa/Team_18_JHB_WhatTheHack_regression-predict-api-template/master/Data/Test.csv')

# %%
test_df.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0  Order_No_19248  User_Id_3355         Bike              3
# 1  Order_No_12736  User_Id_3647         Bike              3
# 2    Order_No_768  User_Id_2154         Bike              3
# 3  Order_No_15332  User_Id_2910         Bike              3
# 4  Order_No_21373  User_Id_1205         Bike              3
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                        27
# 1             Business                        17
# 2             Business                        27
# 3             Business                        17
# 4             Business                        11
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             3       4:44:10 PM                           27
# 1                             5      12:57:35 PM                           17
# 2                             4      11:08:14 AM                           27
# 3                             1       1:51:35 PM                           17
# 4                             2      11:30:28 AM                           11
#
#    Confirmation - Weekday (Mo = 1)  ... Pickup - Weekday (Mo = 1)  \
# 0                                3  ...                         3
# 1                                5  ...                         5
# 2                                4  ...                         4
# 3                                1  ...                         1
# 4                                2  ...                         2
#
#    Pickup - Time  Distance (KM) Temperature  Precipitation in millimeters  \
# 0     5:06:47 PM              8         NaN                           NaN
# 1     1:25:37 PM              5         NaN                           NaN
# 2    11:57:54 AM              5        22.8                           NaN
# 3     2:16:52 PM              5        24.5                           NaN
# 4    11:56:04 AM              6        24.4                           NaN
#
#    Pickup Lat Pickup Long  Destination Lat  Destination Long      Rider Id
# 0   -1.333275   36.870815        -1.305249         36.822390  Rider_Id_192
# 1   -1.272639   36.794723        -1.277007         36.823907  Rider_Id_868
# 2   -1.290894   36.822971        -1.276574         36.851365   Rider_Id_26
# 3   -1.290503   36.809646        -1.303382         36.790658  Rider_Id_685
# 4   -1.281081   36.814423        -1.266467         36.792161  Rider_Id_858
#
# [5 rows x 25 columns]

# %% [markdown]
# riders information

# %%
riders_df=pd.read_csv('https://raw.githubusercontent.com/rufusseopa/Team_18_JHB_WhatTheHack_regression-predict-api-template/master/Data/Riders.csv')

# %%
riders_df.head()
# Out:
#        Rider Id  No_Of_Orders   Age  Average_Rating  No_of_Ratings
# 0  Rider_Id_396          2946  2298            14.0           1159
# 1  Rider_Id_479           360   951            13.5            176
# 2  Rider_Id_648          1746   821            14.3            466
# 3  Rider_Id_753           314   980            12.5             75
# 4  Rider_Id_335           536  1113            13.7            156

# %%
data=pd.merge(left=train_df,right=riders_df,on='Rider Id')
data.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_27440  User_Id_2642         Bike              3
# 2  Order_No_14170  User_Id_3339         Bike              3
# 3  Order_No_21727  User_Id_3523         Bike              3
# 4   Order_No_8301    User_Id_87         Bike              2
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        18
# 2             Business                        31
# 3             Personal                         2
# 4             Personal                        22
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5       3:41:17 PM                           18
# 2                             5      12:51:41 PM                           31
# 3                             2       7:12:10 AM                            2
# 4                             2      10:40:58 AM                           22
#
#    Confirmation - Weekday (Mo = 1)  ... Pickup Lat  Pickup Long  \
# 0                                5  ...  -1.317755    36.830370
# 1                                5  ...  -1.326774    36.787807
# 2                                5  ...  -1.255189    36.782203
# 3                                2  ...  -1.290315    36.757377
# 4                                2  ...  -1.273524    36.799220
#
#    Destination Lat Destination Long      Rider Id  \
# 0        -1.300406        36.829741  Rider_Id_432
# 1        -1.356237        36.904295  Rider_Id_432
# 2        -1.273412        36.818206  Rider_Id_432
# 3        -1.223520        36.802061  Rider_Id_432
# 4        -1.300431        36.752427  Rider_Id_432
#
#    Time from Pickup to Arrival No_Of_Orders   Age  Average_Rating  \
# 0                          745         1637  1309            13.8
# 1                         2886         1637  1309            13.8
# 2                         2615         1637  1309            13.8
# 3                         2986         1637  1309            13.8
# 4                         1602         1637  1309            13.8
#
#   No_of_Ratings
# 0           549
# 1           549
# 2           549
# 3           549
# 4           549
#
# [5 rows x 33 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21201 entries, 0 to 21200
# Data columns (total 33 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Order No                                   21201 non-null  object
#  1   User Id                                    21201 non-null  object
#  2   Vehicle Type                               21201 non-null  object
#  3   Platform Type                              21201 non-null  int64
#  4   Personal or Business                       21201 non-null  object
#  5   Placement - Day of Month                   21201 non-null  int64
#  6   Placement - Weekday (Mo = 1)               21201 non-null  int64
#  7   Placement - Time                           21201 non-null  object
#  8   Confirmation - Day of Month                21201 non-null  int64
#  9   Confirmation - Weekday (Mo = 1)            21201 non-null  int64
#  10  Confirmation - Time                        21201 non-null  object
#  11  Arrival at Pickup - Day of Month           21201 non-null  int64
#  12  Arrival at Pickup - Weekday (Mo = 1)       21201 non-null  int64
#  13  Arrival at Pickup - Time                   21201 non-null  object
#  14  Pickup - Day of Month                      21201 non-null  int64
#  15  Pickup - Weekday (Mo = 1)                  21201 non-null  int64
#  16  Pickup - Time                              21201 non-null  object
#  17  Arrival at Destination - Day of Month      21201 non-null  int64
#  18  Arrival at Destination - Weekday (Mo = 1)  21201 non-null  int64
#  19  Arrival at Destination - Time              21201 non-null  object
#  20  Distance (KM)                              21201 non-null  int64
#  21  Temperature                                16835 non-null  float64
#  22  Precipitation in millimeters               552 non-null    float64
#  23  Pickup Lat                                 21201 non-null  float64
#  24  Pickup Long                                21201 non-null  float64
#  25  Destination Lat                            21201 non-null  float64
#  26  Destination Long                           21201 non-null  float64
#  27  Rider Id                                   21201 non-null  object
#  28  Time from Pickup to Arrival                21201 non-null  int64
#  29  No_Of_Orders                               21201 non-null  int64
#  30  Age                                        21201 non-null  int64
#  31  Average_Rating                             21201 non-null  float64
#  32  No_of_Ratings                              21201 non-null  int64
# dtypes: float64(7), int64(16), object(10)
# memory usage: 5.5+ MB

# %%
data.describe()
# Out:
#        Platform Type  Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# count   21201.000000              21201.000000                  21201.000000
# mean        2.752182                 15.653696                      3.240083
# std         0.625178                  8.798916                      1.567295
# min         1.000000                  1.000000                      1.000000
# 25%         3.000000                  8.000000                      2.000000
# 50%         3.000000                 15.000000                      3.000000
# 75%         3.000000                 23.000000                      5.000000
# max         4.000000                 31.000000                      7.000000
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# count                 21201.000000                     21201.000000
# mean                     15.653837                         3.240225
# std                       8.798886                         1.567228
# min                       1.000000                         1.000000
# 25%                       8.000000                         2.000000
# 50%                      15.000000                         3.000000
# 75%                      23.000000                         5.000000
# max                      31.000000                         7.000000
#
#        Arrival at Pickup - Day of Month  Arrival at Pickup - Weekday (Mo = 1)  \
# count                      21201.000000                          21201.000000
# mean                          15.653837                              3.240225
# std                            8.798886                              1.567228
# min                            1.000000                              1.000000
# 25%                            8.000000                              2.000000
# 50%                           15.000000                              3.000000
# 75%                           23.000000                              5.000000
# max                           31.000000                              7.000000
#
#        Pickup - Day of Month  Pickup - Weekday (Mo = 1)  \
# count           21201.000000               21201.000000
# mean               15.653837                   3.240225
# std                 8.798886                   1.567228
# min                 1.000000                   1.000000
# 25%                 8.000000                   2.000000
# 50%                15.000000                   3.000000
# 75%                23.000000                   5.000000
# max                31.000000                   7.000000
#
#        Arrival at Destination - Day of Month  ...  \
# count                           21201.000000  ...
# mean                               15.653837  ...
# std                                 8.798886  ...
# min                                 1.000000  ...
# 25%                                 8.000000  ...
# 50%                                15.000000  ...
# 75%                                23.000000  ...
# max                                31.000000  ...
#
#        Precipitation in millimeters    Pickup Lat   Pickup Long  \
# count                    552.000000  21201.000000  21201.000000
# mean                       7.905797     -1.281470     36.811264
# std                       17.089971      0.030507      0.037473
# min                        0.100000     -1.438302     36.653621
# 25%                        1.075000     -1.300921     36.784605
# 50%                        2.900000     -1.279395     36.807040
# 75%                        4.900000     -1.257147     36.829741
# max                       99.100000     -1.147170     36.991046
#
#        Destination Lat  Destination Long  Time from Pickup to Arrival  \
# count     21201.000000      21201.000000                 21201.000000
# mean         -1.282581         36.811220                  1556.920947
# std           0.034824          0.044721                   987.270788
# min          -1.430298         36.606594                     1.000000
# 25%          -1.301201         36.785661                   882.000000
# 50%          -1.284382         36.808002                  1369.000000
# 75%          -1.261177         36.829477                  2040.000000
# max          -1.030225         37.016779                  7883.000000
#
#        No_Of_Orders           Age  Average_Rating  No_of_Ratings
# count  21201.000000  21201.000000    21201.000000   21201.000000
# mean    1692.423706    984.742842       13.882520     341.067119
# std     1574.308302    646.652835        0.916071     402.867746
# min        2.000000     96.000000        0.000000       0.000000
# 25%      557.000000    495.000000       13.600000      61.000000
# 50%     1212.000000    872.000000       14.000000     161.000000
# 75%     2311.000000   1236.000000       14.300000     495.000000
# max     9756.000000   3764.000000       15.200000    2298.000000
#
# [8 rows x 23 columns]

# %%
#EDA
data=data.drop('Vehicle Type',axis=1)

# %%
data.head(2)
# Out:
#          Order No       User Id  Platform Type Personal or Business  \
# 0   Order_No_4211   User_Id_633              3             Business
# 1  Order_No_27440  User_Id_2642              3             Personal
#
#    Placement - Day of Month  Placement - Weekday (Mo = 1) Placement - Time  \
# 0                         9                             5       9:35:46 AM
# 1                        18                             5       3:41:17 PM
#
#    Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# 0                            9                                5
# 1                           18                                5
#
#   Confirmation - Time  ...  Pickup Lat  Pickup Long Destination Lat  \
# 0          9:40:10 AM  ...   -1.317755    36.830370       -1.300406
# 1          3:41:30 PM  ...   -1.326774    36.787807       -1.356237
#
#    Destination Long      Rider Id Time from Pickup to Arrival  No_Of_Orders  \
# 0         36.829741  Rider_Id_432                         745          1637
# 1         36.904295  Rider_Id_432                        2886          1637
#
#     Age Average_Rating  No_of_Ratings
# 0  1309           13.8            549
# 1  1309           13.8            549
#
# [2 rows x 32 columns]

# %%
data
# Out:
#              Order No       User Id  Platform Type Personal or Business  \
# 0       Order_No_4211   User_Id_633              3             Business
# 1      Order_No_27440  User_Id_2642              3             Personal
# 2      Order_No_14170  User_Id_3339              3             Business
# 3      Order_No_21727  User_Id_3523              3             Personal
# 4       Order_No_8301    User_Id_87              2             Personal
# ...               ...           ...            ...                  ...
# 21196  Order_No_27103  User_Id_3718              3             Business
# 21197   Order_No_3786  User_Id_1558              3             Personal
# 21198   Order_No_7281  User_Id_2008              3             Business
# 21199  Order_No_15575  User_Id_1346              3             Business
# 21200  Order_No_15578  User_Id_2174              3             Business
#
#        Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# 0                             9                             5
# 1                            18                             5
# 2                            31                             5
# 3                             2                             2
# 4                            22                             2
# ...                         ...                           ...
# 21196                        13                             2
# 21197                        21                             4
# 21198                        10                             1
# 21199                        29                             2
# 21200                        30                             5
#
#       Placement - Time  Confirmation - Day of Month  \
# 0           9:35:46 AM                            9
# 1           3:41:17 PM                           18
# 2          12:51:41 PM                           31
# 3           7:12:10 AM                            2
# 4          10:40:58 AM                           22
# ...                ...                          ...
# 21196      11:09:37 AM                           13
# 21197       4:33:17 PM                           21
# 21198       5:00:40 PM                           10
# 21199       2:31:55 PM                           29
# 21200       9:51:23 AM                           30
#
#        Confirmation - Weekday (Mo = 1) Confirmation - Time  ...  Pickup Lat  \
# 0                                    5          9:40:10 AM  ...   -1.317755
# 1                                    5          3:41:30 PM  ...   -1.326774
# 2                                    5          1:12:49 PM  ...   -1.255189
# 3                                    2          7:12:29 AM  ...   -1.290315
# 4                                    2         10:42:24 AM  ...   -1.273524
# ...                                ...                 ...  ...         ...
# 21196                                2         11:32:18 AM  ...   -1.265003
# 21197                                4          4:47:27 PM  ...   -1.269609
# 21198                                1          5:11:21 PM  ...   -1.250823
# 21199                                2          2:32:43 PM  ...   -1.291787
# 21200                                5          9:51:32 AM  ...   -1.248278
#
#        Pickup Long Destination Lat  Destination Long      Rider Id  \
# 0        36.830370       -1.300406         36.829741  Rider_Id_432
# 1        36.787807       -1.356237         36.904295  Rider_Id_432
# 2        36.782203       -1.273412         36.818206  Rider_Id_432
# 3        36.757377       -1.223520         36.802061  Rider_Id_432
# 4        36.799220       -1.300431         36.752427  Rider_Id_432
# ...            ...             ...               ...           ...
# 21196    36.812624       -1.265432         36.795034  Rider_Id_528
# 21197    36.825741       -1.278067         36.783487  Rider_Id_638
# 21198    36.789526       -1.285850         36.830629  Rider_Id_773
# 21199    36.787267       -1.298575         36.808800  Rider_Id_860
# 21200    36.884092       -1.286808         36.821940   Rider_Id_53
#
#       Time from Pickup to Arrival  No_Of_Orders   Age Average_Rating  \
# 0                             745          1637  1309           13.8
# 1                            2886          1637  1309           13.8
# 2                            2615          1637  1309           13.8
# 3                            2986          1637  1309           13.8
# 4                            1602          1637  1309           13.8
# ...                           ...           ...   ...            ...
# 21196                         919          5770  1793           14.2
# 21197                        2331           102   873           13.7
# 21198                        2418             5   105            0.0
# 21199                         717             5   448           15.0
# 21200                        1647           241  1109           13.7
#
#        No_of_Ratings
# 0                549
# 1                549
# 2                549
# 3                549
# 4                549
# ...              ...
# 21196           2205
# 21197             32
# 21198              0
# 21199              2
# 21200             73
#
# [21201 rows x 32 columns]

# %%
pd.get_dummies(data)
# Out:
#        Platform Type  Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# 0                  3                         9                             5
# 1                  3                        18                             5
# 2                  3                        31                             5
# 3                  3                         2                             2
# 4                  2                        22                             2
# ...              ...                       ...                           ...
# 21196              3                        13                             2
# 21197              3                        21                             4
# 21198              3                        10                             1
# 21199              3                        29                             2
# 21200              3                        30                             5
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# 0                                9                                5
# 1                               18                                5
# 2                               31                                5
# 3                                2                                2
# 4                               22                                2
# ...                            ...                              ...
# 21196                           13                                2
# 21197                           21                                4
# 21198                           10                                1
# 21199                           29                                2
# 21200                           30                                5
#
#        Arrival at Pickup - Day of Month  Arrival at Pickup - Weekday (Mo = 1)  \
# 0                                     9                                     5
# 1                                    18                                     5
# 2                                    31                                     5
# 3                                     2                                     2
# 4                                    22                                     2
# ...                                 ...                                   ...
# 21196                                13                                     2
# 21197                                21                                     4
# 21198                                10                                     1
# 21199                                29                                     2
# 21200                                30                                     5
#
#        Pickup - Day of Month  Pickup - Weekday (Mo = 1)  \
# 0                          9                          5
# 1                         18                          5
# 2                         31                          5
# 3                          2                          2
# 4                         22                          2
# ...                      ...                        ...
# 21196                     13                          2
# 21197                     21                          4
# 21198                     10                          1
# 21199                     29                          2
# 21200                     30                          5
#
#        Arrival at Destination - Day of Month  ...  Rider Id_Rider_Id_953  \
# 0                                          9  ...                      0
# 1                                         18  ...                      0
# 2                                         31  ...                      0
# 3                                          2  ...                      0
# 4                                         22  ...                      0
# ...                                      ...  ...                    ...
# 21196                                     13  ...                      0
# 21197                                     21  ...                      0
# 21198                                     10  ...                      0
# 21199                                     29  ...                      0
# 21200                                     30  ...                      0
#
#        Rider Id_Rider_Id_954  Rider Id_Rider_Id_955  Rider Id_Rider_Id_956  \
# 0                          0                      0                      0
# 1                          0                      0                      0
# 2                          0                      0                      0
# 3                          0                      0                      0
# 4                          0                      0                      0
# ...                      ...                    ...                    ...
# 21196                      0                      0                      0
# 21197                      0                      0                      0
# 21198                      0                      0                      0
# 21199                      0                      0                      0
# 21200                      0                      0                      0
#
#        Rider Id_Rider_Id_958  Rider Id_Rider_Id_959  Rider Id_Rider_Id_96  \
# 0                          0                      0                     0
# 1                          0                      0                     0
# 2                          0                      0                     0
# 3                          0                      0                     0
# 4                          0                      0                     0
# ...                      ...                    ...                   ...
# 21196                      0                      0                     0
# 21197                      0                      0                     0
# 21198                      0                      0                     0
# 21199                      0                      0                     0
# 21200                      0                      0                     0
#
#        Rider Id_Rider_Id_97  Rider Id_Rider_Id_98  Rider Id_Rider_Id_99
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 21196                     0                     0                     0
# 21197                     0                     0                     0
# 21198                     0                     0                     0
# 21199                     0                     0                     0
# 21200                     0                     0                     0
#
# [21201 rows x 103946 columns]

# %%
data.head()
# Out:
#          Order No       User Id  Platform Type Personal or Business  \
# 0   Order_No_4211   User_Id_633              3             Business
# 1  Order_No_27440  User_Id_2642              3             Personal
# 2  Order_No_14170  User_Id_3339              3             Business
# 3  Order_No_21727  User_Id_3523              3             Personal
# 4   Order_No_8301    User_Id_87              2             Personal
#
#    Placement - Day of Month  Placement - Weekday (Mo = 1) Placement - Time  \
# 0                         9                             5       9:35:46 AM
# 1                        18                             5       3:41:17 PM
# 2                        31                             5      12:51:41 PM
# 3                         2                             2       7:12:10 AM
# 4                        22                             2      10:40:58 AM
#
#    Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# 0                            9                                5
# 1                           18                                5
# 2                           31                                5
# 3                            2                                2
# 4                           22                                2
#
#   Confirmation - Time  ...  Pickup Lat  Pickup Long Destination Lat  \
# 0          9:40:10 AM  ...   -1.317755    36.830370       -1.300406
# 1          3:41:30 PM  ...   -1.326774    36.787807       -1.356237
# 2          1:12:49 PM  ...   -1.255189    36.782203       -1.273412
# 3          7:12:29 AM  ...   -1.290315    36.757377       -1.223520
# 4         10:42:24 AM  ...   -1.273524    36.799220       -1.300431
#
#    Destination Long      Rider Id Time from Pickup to Arrival  No_Of_Orders  \
# 0         36.829741  Rider_Id_432                         745          1637
# 1         36.904295  Rider_Id_432                        2886          1637
# 2         36.818206  Rider_Id_432                        2615          1637
# 3         36.802061  Rider_Id_432                        2986          1637
# 4         36.752427  Rider_Id_432                        1602          1637
#
#     Age Average_Rating  No_of_Ratings
# 0  1309           13.8            549
# 1  1309           13.8            549
# 2  1309           13.8            549
# 3  1309           13.8            549
# 4  1309           13.8            549
#
# [5 rows x 32 columns]

# %%
data.columns
# Out:
# Index(['Order No', 'User Id', 'Platform Type', 'Personal or Business',
#        'Placement - Day of Month', 'Placement - Weekday (Mo = 1)',
#        'Placement - Time', 'Confirmation - Day of Month',
#        'Confirmation - Weekday (Mo = 1)', 'Confirmation - Time',
#        'Arrival at Pickup - Day of Month',
#        'Arrival at Pickup - Weekday (Mo = 1)', 'Arrival at Pickup - Time',
#        'Pickup - Day of Month', 'Pickup - Weekday (Mo = 1)', 'Pickup - Time',
#        'Arrival at Destination - Day of Month',
#        'Arrival at Destination - Weekday (Mo = 1)',
#        'Arrival at Destination - Time', 'Distance (KM)', 'Temperature',
#        'Precipitation in millimeters', 'Pickup Lat', 'Pickup Long',
#        'Destination Lat', 'Destination Long', 'Rider Id',
#        'Time from Pickup to Arrival', 'No_Of_Orders', 'Age', 'Average_Rating',
#        'No_of_Ratings'],
#       dtype='object')

# %%
#selecting Features
X=data[['Platform Type', 'Personal or Business', 'Placement - Day of Month',
       'Placement - Weekday (Mo = 1)','Pickup - Day of Month', 'Pickup - Weekday (Mo = 1)','Distance (KM)', 'Temperature','Age']]
y=data['Time from Pickup to Arrival']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21201 entries, 0 to 21200
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Platform Type                 21201 non-null  int64
#  1   Personal or Business          21201 non-null  object
#  2   Placement - Day of Month      21201 non-null  int64
#  3   Placement - Weekday (Mo = 1)  21201 non-null  int64
#  4   Pickup - Day of Month         21201 non-null  int64
#  5   Pickup - Weekday (Mo = 1)     21201 non-null  int64
#  6   Distance (KM)                 21201 non-null  int64
#  7   Temperature                   16835 non-null  float64
#  8   Age                           21201 non-null  int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 1.6+ MB

# %%
X.fillna(X.median(),inplace=True)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21201 entries, 0 to 21200
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Platform Type                 21201 non-null  int64
#  1   Personal or Business          21201 non-null  object
#  2   Placement - Day of Month      21201 non-null  int64
#  3   Placement - Weekday (Mo = 1)  21201 non-null  int64
#  4   Pickup - Day of Month         21201 non-null  int64
#  5   Pickup - Weekday (Mo = 1)     21201 non-null  int64
#  6   Distance (KM)                 21201 non-null  int64
#  7   Temperature                   21201 non-null  float64
#  8   Age                           21201 non-null  int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 1.6+ MB
# /Users/rufusseopa/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
from sklearn.model_selection import train_test_split

# %%
#data wrangling
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct=ColumnTransformer(ColumnTransformer=[('encorder',OneHotEncoder,[0,1])],remainder='passthrough')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-5f4769102283> in <module>()
#       2 from sklearn.preprocessing import OneHotEncoder
#       3 from sklearn.compose import ColumnTransformer
# ----> 4 ct=ColumnTransformer(ColumnTransformer=[('encorder',OneHotEncoder,[0,1])],remainder='passthrough')
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# TypeError: __init__() got an unexpected keyword argument 'ColumnTransformer'

# %%
#encoding categorical varaibles
on=preprocessing.OneHotEncoder()

# %%
X['Personal or Business']

# %%
#Fitting the Transformer APIPython(This for ensuring that means and std are for future use. unlike the scaler)
scaler = preprocessing.StandardScaler().fit([X])

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
#cross validation
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
#Import evaluation metricsPython
from sklearn.metrics import mean_squared_error, r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, random_state=123)

# %%
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train,y_train)
